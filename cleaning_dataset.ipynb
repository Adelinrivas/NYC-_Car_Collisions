# %%
import pandas as pd

# %%
 car_collissions= pd.read_csv("Motor_Vehicle_Collisions_-_Crashes_2017-2021.csv")

# %%
car_collissions.describe()
# Out:
#             ZIP CODE       LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  574943.000000  833389.000000  833389.000000              897485.000000
# mean    10871.450453      40.641292     -73.777958                   0.312395
# std       540.935530       1.848890       3.611964                   0.695808
# min     10000.000000       0.000000    -201.237060                   0.000000
# 25%     10453.000000      40.667580     -73.970350                   0.000000
# 50%     11208.000000      40.720016     -73.922400                   0.000000
# 75%     11249.000000      40.774612     -73.863560                   0.000000
# max     11697.000000      41.126150       0.000000                  31.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count             897472.000000                  897502.000000
# mean                   0.001441                       0.052407
# std                    0.040183                       0.235473
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
car_collissions.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  01/01/2017      14:00       NaN       NaN        NaN        NaN
# 1  01/01/2017       9:45       NaN       NaN        NaN        NaN
# 2  01/01/2017       3:32  BROOKLYN   11237.0  40.709330  -73.92249
# 3  01/01/2017       8:00       NaN       NaN  40.666233  -73.76100
# 4  01/01/2017      10:20    QUEENS   11372.0  40.751003  -73.89213
#
#                  LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0                     NaN                               NaN               NaN
# 1                     NaN  SHORE PARKWAY                         KNAPP STREET
# 2   (40.70933, -73.92249)  JOHNSON AVENUE                        SCOTT AVENUE
# 3    (40.666233, -73.761)  BELT PARKWAY                                   NaN
# 4  (40.751003, -73.89213)  35 AVENUE                                74 STREET
#
#   OFF STREET NAME  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# ...

# %%
car_collissions=car_collissions.drop(['CONTRIBUTING FACTOR VEHICLE 3','CONTRIBUTING FACTOR VEHICLE 4','CONTRIBUTING FACTOR VEHICLE 5'], axis=1)

# %%
car_collissions
# Out:
#         CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       01/01/2017      14:00       NaN       NaN        NaN        NaN
# 1       01/01/2017       9:45       NaN       NaN        NaN        NaN
# 2       01/01/2017       3:32  BROOKLYN   11237.0  40.709330 -73.922490
# 3       01/01/2017       8:00       NaN       NaN  40.666233 -73.761000
# 4       01/01/2017      10:20    QUEENS   11372.0  40.751003 -73.892130
# ...            ...        ...       ...       ...        ...        ...
# 897497  12/31/2021      10:37  BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15    QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23     BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26  BROOKLYN   11212.0  40.669262 -73.913560
# 897501  12/31/2021       2:15       NaN       NaN  40.788795 -73.937550
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
car_collissions=car_collissions.drop(['VEHICLE TYPE CODE 3','VEHICLE TYPE CODE 4','VEHICLE TYPE CODE 5'], axis=1)

# %%
car_collissions
# Out:
#         CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       01/01/2017      14:00       NaN       NaN        NaN        NaN
# 1       01/01/2017       9:45       NaN       NaN        NaN        NaN
# 2       01/01/2017       3:32  BROOKLYN   11237.0  40.709330 -73.922490
# 3       01/01/2017       8:00       NaN       NaN  40.666233 -73.761000
# 4       01/01/2017      10:20    QUEENS   11372.0  40.751003 -73.892130
# ...            ...        ...       ...       ...        ...        ...
# 897497  12/31/2021      10:37  BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15    QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23     BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26  BROOKLYN   11212.0  40.669262 -73.913560
# 897501  12/31/2021       2:15       NaN       NaN  40.788795 -73.937550
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
list_col=list(car_collissions)

# %%
car_collissions=car_collissions.dropna(subset =list_col[0:7])
car_collissions
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2       01/01/2017       3:32   BROOKLYN   11237.0  40.709330 -73.922490
# 4       01/01/2017      10:20     QUEENS   11372.0  40.751003 -73.892130
# 5       01/01/2017      16:15  MANHATTAN   10027.0  40.807770 -73.945490
# 6       01/01/2017      11:01  MANHATTAN   10017.0  40.751120 -73.971270
# 7       01/01/2017       0:00   BROOKLYN   11210.0  40.632427 -73.940830
# ...            ...        ...        ...       ...        ...        ...
# 897496  12/31/2021      19:45   BROOKLYN   11214.0  40.599380 -73.997730
# 897497  12/31/2021      10:37   BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15     QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23      BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26   BROOKLYN   11212.0  40.669262 -73.913560
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
car_collissions
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2       01/01/2017       3:32   BROOKLYN   11237.0  40.709330 -73.922490
# 4       01/01/2017      10:20     QUEENS   11372.0  40.751003 -73.892130
# 5       01/01/2017      16:15  MANHATTAN   10027.0  40.807770 -73.945490
# 6       01/01/2017      11:01  MANHATTAN   10017.0  40.751120 -73.971270
# 7       01/01/2017       0:00   BROOKLYN   11210.0  40.632427 -73.940830
# ...            ...        ...        ...       ...        ...        ...
# 897496  12/31/2021      19:45   BROOKLYN   11214.0  40.599380 -73.997730
# 897497  12/31/2021      10:37   BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15     QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23      BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26   BROOKLYN   11212.0  40.669262 -73.913560
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
car_collissions['CROSS STREET NAME'].fillna('', inplace=True)
# Out:
# /tmp/ipykernel_82843/3117046194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['CROSS STREET NAME'].fillna('', inplace=True)

# %%
car_collissions
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2       01/01/2017       3:32   BROOKLYN   11237.0  40.709330 -73.922490
# 4       01/01/2017      10:20     QUEENS   11372.0  40.751003 -73.892130
# 5       01/01/2017      16:15  MANHATTAN   10027.0  40.807770 -73.945490
# 6       01/01/2017      11:01  MANHATTAN   10017.0  40.751120 -73.971270
# 7       01/01/2017       0:00   BROOKLYN   11210.0  40.632427 -73.940830
# ...            ...        ...        ...       ...        ...        ...
# 897496  12/31/2021      19:45   BROOKLYN   11214.0  40.599380 -73.997730
# 897497  12/31/2021      10:37   BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15     QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23      BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26   BROOKLYN   11212.0  40.669262 -73.913560
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
car_collissions['ON STREET NAME'].fillna('', inplace=True)
# Out:
# /tmp/ipykernel_82843/3736980180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['ON STREET NAME'].fillna('', inplace=True)

# %%
car_collissions
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2       01/01/2017       3:32   BROOKLYN   11237.0  40.709330 -73.922490
# 4       01/01/2017      10:20     QUEENS   11372.0  40.751003 -73.892130
# 5       01/01/2017      16:15  MANHATTAN   10027.0  40.807770 -73.945490
# 6       01/01/2017      11:01  MANHATTAN   10017.0  40.751120 -73.971270
# 7       01/01/2017       0:00   BROOKLYN   11210.0  40.632427 -73.940830
# ...            ...        ...        ...       ...        ...        ...
# 897496  12/31/2021      19:45   BROOKLYN   11214.0  40.599380 -73.997730
# 897497  12/31/2021      10:37   BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15     QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23      BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26   BROOKLYN   11212.0  40.669262 -73.913560
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
car_collissions['OFF STREET NAME'].fillna('', inplace=True)
# Out:
# /tmp/ipykernel_82843/1217189032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['OFF STREET NAME'].fillna('', inplace=True)

# %%
car_collissions
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2       01/01/2017       3:32   BROOKLYN   11237.0  40.709330 -73.922490
# 4       01/01/2017      10:20     QUEENS   11372.0  40.751003 -73.892130
# 5       01/01/2017      16:15  MANHATTAN   10027.0  40.807770 -73.945490
# 6       01/01/2017      11:01  MANHATTAN   10017.0  40.751120 -73.971270
# 7       01/01/2017       0:00   BROOKLYN   11210.0  40.632427 -73.940830
# ...            ...        ...        ...       ...        ...        ...
# 897496  12/31/2021      19:45   BROOKLYN   11214.0  40.599380 -73.997730
# 897497  12/31/2021      10:37   BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15     QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23      BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26   BROOKLYN   11212.0  40.669262 -73.913560
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
#pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', None)

# %%
car_collissions['CONTRIBUTING FACTOR VEHICLE 2'].fillna('', inplace=True)
# Out:
# /tmp/ipykernel_82843/838924972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['CONTRIBUTING FACTOR VEHICLE 2'].fillna('', inplace=True)

# %%
car_collissions
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2       01/01/2017       3:32   BROOKLYN   11237.0  40.709330 -73.922490
# 4       01/01/2017      10:20     QUEENS   11372.0  40.751003 -73.892130
# 5       01/01/2017      16:15  MANHATTAN   10027.0  40.807770 -73.945490
# 6       01/01/2017      11:01  MANHATTAN   10017.0  40.751120 -73.971270
# 7       01/01/2017       0:00   BROOKLYN   11210.0  40.632427 -73.940830
# ...            ...        ...        ...       ...        ...        ...
# 897496  12/31/2021      19:45   BROOKLYN   11214.0  40.599380 -73.997730
# 897497  12/31/2021      10:37   BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15     QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23      BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26   BROOKLYN   11212.0  40.669262 -73.913560
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
car_collissions['VEHICLE TYPE CODE 2'].fillna('', inplace=True)
# Out:
# /tmp/ipykernel_82843/597436489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['VEHICLE TYPE CODE 2'].fillna('', inplace=True)

# %%
car_collissions
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 2       01/01/2017       3:32   BROOKLYN   11237.0  40.709330 -73.922490
# 4       01/01/2017      10:20     QUEENS   11372.0  40.751003 -73.892130
# 5       01/01/2017      16:15  MANHATTAN   10027.0  40.807770 -73.945490
# 6       01/01/2017      11:01  MANHATTAN   10017.0  40.751120 -73.971270
# 7       01/01/2017       0:00   BROOKLYN   11210.0  40.632427 -73.940830
# ...            ...        ...        ...       ...        ...        ...
# 897496  12/31/2021      19:45   BROOKLYN   11214.0  40.599380 -73.997730
# 897497  12/31/2021      10:37   BROOKLYN   11213.0  40.678880 -73.935610
# 897498  12/31/2021      11:15     QUEENS   11103.0  40.755394 -73.911964
# 897499  12/31/2021      14:23      BRONX   10461.0  40.841390 -73.834680
# 897500  12/31/2021      17:26   BROOKLYN   11212.0  40.669262 -73.913560
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
def checkFornull():
    for col in list(car_collissions):
        
        print(car_collissions[col].isnull().values.any(), end=" ")
        print(col)

# %%
checkFornull()
# Out:
# False CRASH DATE
# False CRASH TIME
# False BOROUGH
# False ZIP CODE
# False LATITUDE
# False LONGITUDE
# False LOCATION
# False ON STREET NAME
# False CROSS STREET NAME
# False OFF STREET NAME
# True NUMBER OF PERSONS INJURED
# True NUMBER OF PERSONS KILLED
# False NUMBER OF PEDESTRIANS INJURED
# False NUMBER OF PEDESTRIANS KILLED
# False NUMBER OF CYCLIST INJURED
# False NUMBER OF CYCLIST KILLED
# False NUMBER OF MOTORIST INJURED
# False NUMBER OF MOTORIST KILLED
# True CONTRIBUTING FACTOR VEHICLE 1
# False CONTRIBUTING FACTOR VEHICLE 2
# False COLLISION_ID
# True VEHICLE TYPE CODE 1
# False VEHICLE TYPE CODE 2

# %%
car_collissions['VEHICLE TYPE CODE 1'].fillna('', inplace=True)
# Out:
# /tmp/ipykernel_82843/1193355066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['VEHICLE TYPE CODE 1'].fillna('', inplace=True)

# %%
checkFornull()
# Out:
# False CRASH DATE
# False CRASH TIME
# False BOROUGH
# False ZIP CODE
# False LATITUDE
# False LONGITUDE
# False LOCATION
# False ON STREET NAME
# False CROSS STREET NAME
# False OFF STREET NAME
# True NUMBER OF PERSONS INJURED
# True NUMBER OF PERSONS KILLED
# False NUMBER OF PEDESTRIANS INJURED
# False NUMBER OF PEDESTRIANS KILLED
# False NUMBER OF CYCLIST INJURED
# False NUMBER OF CYCLIST KILLED
# False NUMBER OF MOTORIST INJURED
# False NUMBER OF MOTORIST KILLED
# True CONTRIBUTING FACTOR VEHICLE 1
# False CONTRIBUTING FACTOR VEHICLE 2
# False COLLISION_ID
# False VEHICLE TYPE CODE 1
# False VEHICLE TYPE CODE 2

# %%
car_collissions['CONTRIBUTING FACTOR VEHICLE 1'].fillna('', inplace=True)
# Out:
# /tmp/ipykernel_82843/83935837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['CONTRIBUTING FACTOR VEHICLE 1'].fillna('', inplace=True)

# %%
checkFornull()
# Out:
# False CRASH DATE
# False CRASH TIME
# False BOROUGH
# False ZIP CODE
# False LATITUDE
# False LONGITUDE
# False LOCATION
# False ON STREET NAME
# False CROSS STREET NAME
# False OFF STREET NAME
# True NUMBER OF PERSONS INJURED
# True NUMBER OF PERSONS KILLED
# False NUMBER OF PEDESTRIANS INJURED
# False NUMBER OF PEDESTRIANS KILLED
# False NUMBER OF CYCLIST INJURED
# False NUMBER OF CYCLIST KILLED
# False NUMBER OF MOTORIST INJURED
# False NUMBER OF MOTORIST KILLED
# False CONTRIBUTING FACTOR VEHICLE 1
# False CONTRIBUTING FACTOR VEHICLE 2
# False COLLISION_ID
# False VEHICLE TYPE CODE 1
# False VEHICLE TYPE CODE 2

# %%
car_collissions['NUMBER OF PERSONS INJURED'].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_82843/3736875126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['NUMBER OF PERSONS INJURED'].fillna(0, inplace=True)

# %%
car_collissions['NUMBER OF PERSONS KILLED'].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_82843/576131576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_collissions['NUMBER OF PERSONS KILLED'].fillna(0, inplace=True)

# %%
checkFornull()
# Out:
# False CRASH DATE
# False CRASH TIME
# False BOROUGH
# False ZIP CODE
# False LATITUDE
# False LONGITUDE
# False LOCATION
# False ON STREET NAME
# False CROSS STREET NAME
# False OFF STREET NAME
# False NUMBER OF PERSONS INJURED
# False NUMBER OF PERSONS KILLED
# False NUMBER OF PEDESTRIANS INJURED
# False NUMBER OF PEDESTRIANS KILLED
# False NUMBER OF CYCLIST INJURED
# False NUMBER OF CYCLIST KILLED
# False NUMBER OF MOTORIST INJURED
# False NUMBER OF MOTORIST KILLED
# False CONTRIBUTING FACTOR VEHICLE 1
# False CONTRIBUTING FACTOR VEHICLE 2
# False COLLISION_ID
# False VEHICLE TYPE CODE 1
# False VEHICLE TYPE CODE 2

# %%
car_collissions.to_csv('nyc_traffic_collision_clean.csv', index=False)
